# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas as pd
import seaborn as sns
import numpy as np
sns.set();

# %%
df= pd.read_excel("../data/coalpublic2019.xls", header=3, index_col='MSHA ID')

# %%
df.head()
# Out:
#          Year                    Mine Name Mine State Mine County Mine Status  \
# MSHA ID
# 103489   2019                John Poe Mine    Alabama     De Kalb      Active
# 100329   2019  Oak Grove Preparation Plant    Alabama   Jefferson      Active
# 100627   2019                Flat Top Mine    Alabama   Jefferson      Active
# 100851   2019               Oak Grove Mine    Alabama   Jefferson      Active
# 101401   2019                    No 7 Mine    Alabama   Jefferson      Active
#
#            Mine Type                  Company Type  \
# MSHA ID
# 103489       Surface  Indepedent Producer Operator
# 100329   Underground  Indepedent Producer Operator
# 100627       Surface  Indepedent Producer Operator
# 100851   Underground  Indepedent Producer Operator
# 101401   Underground  Indepedent Producer Operator
#
#                      Operation Type              Operating Company  \
# MSHA ID
# 103489                    Mine only  Kennedy Brothers Construction
# ...

# %%
df['Company Type'].unique()
# Out:
# array(['Indepedent Producer Operator', 'Operating Subsidiary',
#        'Contractor'], dtype=object)

# %%
df['Company Type'].replace(to_replace='Indepedent Producer Operator', 
                           value='Independent Producer Operator',
                          inplace=True)

# %%
df.head()
# Out:
#          Year                    Mine Name Mine State Mine County Mine Status  \
# MSHA ID
# 103489   2019                John Poe Mine    Alabama     De Kalb      Active
# 100329   2019  Oak Grove Preparation Plant    Alabama   Jefferson      Active
# 100627   2019                Flat Top Mine    Alabama   Jefferson      Active
# 100851   2019               Oak Grove Mine    Alabama   Jefferson      Active
# 101401   2019                    No 7 Mine    Alabama   Jefferson      Active
#
#            Mine Type                   Company Type  \
# MSHA ID
# 103489       Surface  Independent Producer Operator
# 100329   Underground  Independent Producer Operator
# 100627       Surface  Independent Producer Operator
# 100851   Underground  Independent Producer Operator
# 101401   Underground  Independent Producer Operator
#
#                      Operation Type              Operating Company  \
# MSHA ID
# 103489                    Mine only  Kennedy Brothers Construction
# ...

# %%
df.rename(columns=lambda x: x.replace (" ","_"), inplace=True)

# %%
df.head()
# Out:
#          Year                    Mine_Name Mine_State Mine_County Mine_Status  \
# MSHA ID
# 103489   2019                John Poe Mine    Alabama     De Kalb      Active
# 100329   2019  Oak Grove Preparation Plant    Alabama   Jefferson      Active
# 100627   2019                Flat Top Mine    Alabama   Jefferson      Active
# 100851   2019               Oak Grove Mine    Alabama   Jefferson      Active
# 101401   2019                    No 7 Mine    Alabama   Jefferson      Active
#
#            Mine_Type                   Company_Type  \
# MSHA ID
# 103489       Surface  Independent Producer Operator
# 100329   Underground  Independent Producer Operator
# 100627       Surface  Independent Producer Operator
# 100851   Underground  Independent Producer Operator
# 101401   Underground  Independent Producer Operator
#
#                      Operation_Type              Operating_Company  \
# MSHA ID
# 103489                    Mine only  Kennedy Brothers Construction
# ...

# %%
len(df)
# Out:
# 934

# %%
plt.scatter(df.Average_Employees, df.Labor_Hours)
plt.xlabel("Number of Employees")
plt.ylabel("Total Number of Hours")
# Out:
# Text(0, 0.5, 'Total Number of Hours')

# %%
sns.regplot(df.Average_Employees, df.Labor_Hours)
# Out:
# /home/ajor/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Average_Employees', ylabel='Labor_Hours'>

# %%
plt.savefig("../figures/2021-08-27-AJOR-Employees_vs_Hours")

# %%
for column in df.columns:
    print (column)
# Out:
# Year
# Mine_Name
# Mine_State
# Mine_County
# Mine_Status
# Mine_Type
# Company_Type
# Operation_Type
# Operating_Company
# Operating_Company_Address
# Union_Code
# Coal_Supply_Region
# Production_(short_tons)
# Average_Employees
# Labor_Hours

# %%
plt.scatter(df.Labor_Hours, df['Production_(short_tons)'])

# %%
df['Production_(short_tons)'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Production_(short_tons)']==0
# Out:
# MSHA ID
# 103489     False
# 100329      True
# 100627     False
# 100851     False
# 101401     False
#            ...
# 3609843    False
# 3609178    False
# 1103131    False
# 1519450    False
# 4407385    False
# Name: Production_(short_tons), Length: 934, dtype: bool

# %%
df[df['Production_(short_tons)']==0]
# Out:
#          Year                      Mine_Name                Mine_State  \
# MSHA ID
# 100329   2019    Oak Grove Preparation Plant                   Alabama
# 103101   2019               Pratt No. 1 Mine                   Alabama
# 102976   2019  Piney Woods Preparation Plant                   Alabama
# 102976   2019  Piney Woods Preparation Plant                   Alabama
# 103380   2019                         Calera                   Alabama
# ...       ...                            ...                       ...
# 4604637  2019        Kepler No. 1 Prep Plant  West Virginia (Southern)
# 4605868  2019  Ranger Fuel Preparation Plant  West Virginia (Southern)
# 4605868  2019  Ranger Fuel Preparation Plant  West Virginia (Southern)
# 4609316  2019                      K-2 Plant  West Virginia (Southern)
# 4609316  2019                      K-2 Plant  West Virginia (Southern)
#
#         Mine_County         Mine_Status    Mine_Type  \
# MSHA ID
# ...

# %% [markdown]
# Here we are going to slice the data

# %%
df=df[df['Production_(short_tons)']>0]

# %%
len(df)
# Out:
# 669

# %%
df['Log_Production']=np.log(df['Production_(short_tons)'])
# Out:
# <ipython-input-45-df324a148256>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Log_Production']=np.log(df['Production_(short_tons)'])

# %%
df.Log_Production.hist()
# Out:
# <AxesSubplot:>

# %%
df.to_csv("../data/clean_coalpublic2019_log.xls")
